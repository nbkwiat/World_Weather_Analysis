# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
  
    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | saint-augustin
# Processing Record 3 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | ayr
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | dzilam gonzalez
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | uusikaupunki
# Processing Record 19 of Set 1 | korla
# Processing Record 20 of Set 1 | tromso
# Processing Record 21 of Set 1 | zhigansk
# Processing Record 22 of Set 1 | sobolevo
# Processing Record 23 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | gat
# Processing Record 26 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | dong hoi
# Processing Record 30 of Set 1 | beroroha
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | barraute
# Processing Record 33 of Set 1 | praia da vitoria
# Processing Record 34 of Set 1 | qesarya
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | doume
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | henties bay
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | romny
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 1 | abnub
# Processing Record 50 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 2 | monrovia
# Processing Record 5 of Set 2 | bilibino
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | lazaro cardenas
# Processing Record 13 of Set 2 | fortuna
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | camacha
# Processing Record 17 of Set 2 | honningsvag
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | bayir
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | krasnoselkup
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | umtata
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | san policarpo
# Processing Record 29 of Set 2 | calamar
# Processing Record 30 of Set 2 | mahanoro
# Processing Record 31 of Set 2 | chokwe
# Processing Record 32 of Set 2 | pizhma
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | vardo
# Processing Record 39 of Set 2 | constitucion
# Processing Record 40 of Set 2 | sioux lookout
# Processing Record 41 of Set 2 | cam ranh
# Processing Record 42 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 43 of Set 2 | buckeye
# Processing Record 44 of Set 2 | celestun
# Processing Record 45 of Set 2 | rangpur
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | corowa
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | ushuaia
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | mandera
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | pacific grove
# Processing Record 8 of Set 3 | tambul
# City not found. Skipping...
# Processing Record 9 of Set 3 | sitka
# Processing Record 10 of Set 3 | mount pleasant
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | pundaguitan
# Processing Record 14 of Set 3 | telchac
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | saint-joseph
# Processing Record 17 of Set 3 | san cristobal
# Processing Record 18 of Set 3 | de-kastri
# Processing Record 19 of Set 3 | port macquarie
# Processing Record 20 of Set 3 | simao
# Processing Record 21 of Set 3 | ratnagiri
# Processing Record 22 of Set 3 | omboue
# Processing Record 23 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | paungde
# Processing Record 25 of Set 3 | mirzapur
# Processing Record 26 of Set 3 | kurilsk
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | ilam
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | poya
# Processing Record 32 of Set 3 | high rock
# Processing Record 33 of Set 3 | bathsheba
# Processing Record 34 of Set 3 | amapa
# Processing Record 35 of Set 3 | maniitsoq
# Processing Record 36 of Set 3 | puerto ayacucho
# Processing Record 37 of Set 3 | hradek
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | marzuq
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | alyangula
# Processing Record 43 of Set 3 | olinda
# Processing Record 44 of Set 3 | padang
# Processing Record 45 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 3 | bo phloi
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | sur
# Processing Record 49 of Set 3 | alofi
# Processing Record 50 of Set 3 | klaksvik
# Processing Record 1 of Set 4 | biak
# Processing Record 2 of Set 4 | huarmey
# Processing Record 3 of Set 4 | ban dung
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | bojnurd
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | palana
# Processing Record 9 of Set 4 | vostochnyy
# Processing Record 10 of Set 4 | pervomayskoye
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | botwood
# Processing Record 13 of Set 4 | solnechnyy
# Processing Record 14 of Set 4 | banda aceh
# Processing Record 15 of Set 4 | acajutla
# Processing Record 16 of Set 4 | tanete
# Processing Record 17 of Set 4 | wageningen
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | mayo
# Processing Record 20 of Set 4 | yulara
# Processing Record 21 of Set 4 | neiafu
# Processing Record 22 of Set 4 | rehoboth
# Processing Record 23 of Set 4 | svetlogorsk
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | diego de almagro
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | sorland
# Processing Record 28 of Set 4 | orbetello
# Processing Record 29 of Set 4 | minggang
# Processing Record 30 of Set 4 | ust-tsilma
# Processing Record 31 of Set 4 | cajaruro
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | oranjemund
# Processing Record 34 of Set 4 | yar-sale
# Processing Record 35 of Set 4 | mandalgovi
# Processing Record 36 of Set 4 | muzquiz
# City not found. Skipping...
# Processing Record 37 of Set 4 | haizhou
# Processing Record 38 of Set 4 | tieli
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | basco
# Processing Record 41 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | zemio
# Processing Record 45 of Set 4 | tigil
# Processing Record 46 of Set 4 | cassilandia
# Processing Record 47 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 48 of Set 4 | olafsvik
# Processing Record 49 of Set 4 | vitim
# Processing Record 50 of Set 4 | tuatapere
# Processing Record 1 of Set 5 | trinidad
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | banjar
# Processing Record 5 of Set 5 | russell
# Processing Record 6 of Set 5 | sivaki
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | kropotkin
# Processing Record 9 of Set 5 | the valley
# Processing Record 10 of Set 5 | sept-iles
# Processing Record 11 of Set 5 | yarkovo
# Processing Record 12 of Set 5 | stephenville
# Processing Record 13 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 5 | vao
# Processing Record 15 of Set 5 | ogawa
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | ayan
# Processing Record 18 of Set 5 | lompoc
# Processing Record 19 of Set 5 | merauke
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | lillooet
# Processing Record 22 of Set 5 | coquimbo
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | shache
# Processing Record 25 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 5 | maningrida
# Processing Record 27 of Set 5 | choctaw
# Processing Record 28 of Set 5 | shitanjing
# Processing Record 29 of Set 5 | lufilufi
# Processing Record 30 of Set 5 | laguna
# Processing Record 31 of Set 5 | zhezkazgan
# Processing Record 32 of Set 5 | kingsland
# Processing Record 33 of Set 5 | superior
# Processing Record 34 of Set 5 | plettenberg bay
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | ternate
# Processing Record 37 of Set 5 | mumford
# Processing Record 38 of Set 5 | san andres
# Processing Record 39 of Set 5 | santiago
# Processing Record 40 of Set 5 | surt
# Processing Record 41 of Set 5 | mattru
# Processing Record 42 of Set 5 | shieli
# Processing Record 43 of Set 5 | sakaiminato
# Processing Record 44 of Set 5 | portland
# Processing Record 45 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 5 | iracoubo
# Processing Record 47 of Set 5 | angoche
# Processing Record 48 of Set 5 | pizhanka
# Processing Record 49 of Set 5 | vicente guerrero
# Processing Record 50 of Set 5 | bayan
# Processing Record 1 of Set 6 | port shepstone
# Processing Record 2 of Set 6 | kayseri
# Processing Record 3 of Set 6 | wilson
# Processing Record 4 of Set 6 | marinette
# Processing Record 5 of Set 6 | kalianget
# Processing Record 6 of Set 6 | okhotsk
# Processing Record 7 of Set 6 | hobyo
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | sorong
# Processing Record 10 of Set 6 | hukuntsi
# Processing Record 11 of Set 6 | trairi
# Processing Record 12 of Set 6 | kysyl-syr
# Processing Record 13 of Set 6 | airai
# Processing Record 14 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 6 | marathon
# Processing Record 16 of Set 6 | tasiilaq
# Processing Record 17 of Set 6 | atambua
# Processing Record 18 of Set 6 | medvedovskaya
# Processing Record 19 of Set 6 | yerbogachen
# Processing Record 20 of Set 6 | los llanos de aridane
# Processing Record 21 of Set 6 | paamiut
# Processing Record 22 of Set 6 | aldan
# Processing Record 23 of Set 6 | belaya gora
# Processing Record 24 of Set 6 | praia
# Processing Record 25 of Set 6 | kabalo
# Processing Record 26 of Set 6 | puerto del rosario
# Processing Record 27 of Set 6 | orchard homes
# Processing Record 28 of Set 6 | adrar
# Processing Record 29 of Set 6 | atasu
# Processing Record 30 of Set 6 | panaba
# Processing Record 31 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 6 | vannes
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | qiongshan
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | asfi
# Processing Record 38 of Set 6 | bambous virieux
# Processing Record 39 of Set 6 | khash
# Processing Record 40 of Set 6 | caravelas
# Processing Record 41 of Set 6 | havelock
# Processing Record 42 of Set 6 | baoding
# Processing Record 43 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 44 of Set 6 | aljezur
# Processing Record 45 of Set 6 | victoria
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | auki
# Processing Record 48 of Set 6 | kigonsera
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | rio grande
# Processing Record 1 of Set 7 | bestobe
# Processing Record 2 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 7 | yangambi
# Processing Record 4 of Set 7 | champerico
# Processing Record 5 of Set 7 | atuona
# Processing Record 6 of Set 7 | tazovskiy
# Processing Record 7 of Set 7 | kasongo-lunda
# Processing Record 8 of Set 7 | gladstone
# Processing Record 9 of Set 7 | poum
# Processing Record 10 of Set 7 | matagami
# Processing Record 11 of Set 7 | hofn
# Processing Record 12 of Set 7 | ilhabela
# Processing Record 13 of Set 7 | mitu
# Processing Record 14 of Set 7 | esperance
# Processing Record 15 of Set 7 | conde
# Processing Record 16 of Set 7 | aron
# Processing Record 17 of Set 7 | khani
# Processing Record 18 of Set 7 | north bend
# Processing Record 19 of Set 7 | grand gaube
# Processing Record 20 of Set 7 | xining
# Processing Record 21 of Set 7 | ergani
# Processing Record 22 of Set 7 | chibombo
# Processing Record 23 of Set 7 | shubarshi
# Processing Record 24 of Set 7 | sungairaya
# Processing Record 25 of Set 7 | souillac
# Processing Record 26 of Set 7 | half moon bay
# Processing Record 27 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 7 | moose factory
# Processing Record 29 of Set 7 | hasaki
# Processing Record 30 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 7 | jining
# Processing Record 32 of Set 7 | rodos
# Processing Record 33 of Set 7 | sesheke
# Processing Record 34 of Set 7 | mahajanga
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | tateyama
# Processing Record 37 of Set 7 | taltal
# Processing Record 38 of Set 7 | aykhal
# Processing Record 39 of Set 7 | borodino
# Processing Record 40 of Set 7 | garowe
# Processing Record 41 of Set 7 | pakwach
# City not found. Skipping...
# Processing Record 42 of Set 7 | atar
# Processing Record 43 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 7 | nicoya
# Processing Record 45 of Set 7 | corabia
# Processing Record 46 of Set 7 | severnyy
# Processing Record 47 of Set 7 | ladario
# Processing Record 48 of Set 7 | faanui
# Processing Record 49 of Set 7 | mae sai
# Processing Record 50 of Set 7 | lasa
# Processing Record 1 of Set 8 | ambilobe
# Processing Record 2 of Set 8 | roald
# Processing Record 3 of Set 8 | verkhnevilyuysk
# Processing Record 4 of Set 8 | hammel
# Processing Record 5 of Set 8 | bac lieu
# Processing Record 6 of Set 8 | miles city
# Processing Record 7 of Set 8 | muzhi
# Processing Record 8 of Set 8 | wajima
# Processing Record 9 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 8 | carmarthen
# Processing Record 11 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 8 | vitoria do mearim
# Processing Record 13 of Set 8 | manggar
# Processing Record 14 of Set 8 | malindi
# Processing Record 15 of Set 8 | margate
# Processing Record 16 of Set 8 | boromlya
# Processing Record 17 of Set 8 | port lincoln
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | la ronge
# Processing Record 20 of Set 8 | buala
# Processing Record 21 of Set 8 | mezen
# Processing Record 22 of Set 8 | ostrovnoy
# Processing Record 23 of Set 8 | ixtapa
# Processing Record 24 of Set 8 | aasiaat
# Processing Record 25 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 8 | hondo
# Processing Record 27 of Set 8 | felipe carrillo puerto
# Processing Record 28 of Set 8 | samarai
# Processing Record 29 of Set 8 | saint-ambroise
# Processing Record 30 of Set 8 | makakilo city
# Processing Record 31 of Set 8 | klyuchi
# Processing Record 32 of Set 8 | williams lake
# Processing Record 33 of Set 8 | foz do iguacu
# Processing Record 34 of Set 8 | dikson
# Processing Record 35 of Set 8 | byumba
# Processing Record 36 of Set 8 | romitan
# Processing Record 37 of Set 8 | karratha
# Processing Record 38 of Set 8 | mogadishu
# Processing Record 39 of Set 8 | nemuro
# Processing Record 40 of Set 8 | colares
# Processing Record 41 of Set 8 | faya
# Processing Record 42 of Set 8 | muli
# Processing Record 43 of Set 8 | san patricio
# Processing Record 44 of Set 8 | high level
# Processing Record 45 of Set 8 | ust-nera
# Processing Record 46 of Set 8 | oksfjord
# Processing Record 47 of Set 8 | sedhiou
# Processing Record 48 of Set 8 | yaan
# Processing Record 49 of Set 8 | nizhniy kuranakh
# Processing Record 50 of Set 8 | tefe
# Processing Record 1 of Set 9 | sicuani
# Processing Record 2 of Set 9 | axim
# Processing Record 3 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 9 | novikovo
# Processing Record 5 of Set 9 | gushikawa
# Processing Record 6 of Set 9 | codrington
# Processing Record 7 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | burica
# City not found. Skipping...
# Processing Record 9 of Set 9 | tabou
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | turukhansk
# Processing Record 12 of Set 9 | gizo
# Processing Record 13 of Set 9 | yerofey pavlovich
# Processing Record 14 of Set 9 | penzance
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | rocha
# Processing Record 17 of Set 9 | iskateley
# Processing Record 18 of Set 9 | choma
# Processing Record 19 of Set 9 | solwezi
# Processing Record 20 of Set 9 | clonakilty
# Processing Record 21 of Set 9 | ewa beach
# Processing Record 22 of Set 9 | mitsamiouli
# Processing Record 23 of Set 9 | kulu
# Processing Record 24 of Set 9 | itzehoe
# Processing Record 25 of Set 9 | two rivers
# Processing Record 26 of Set 9 | elk point
# Processing Record 27 of Set 9 | novo lino
# Processing Record 28 of Set 9 | boa vista
# Processing Record 29 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 30 of Set 9 | bairiki
# Processing Record 31 of Set 9 | dalnegorsk
# Processing Record 32 of Set 9 | safford
# Processing Record 33 of Set 9 | salalah
# Processing Record 34 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 9 | andros town
# Processing Record 36 of Set 9 | maldonado
# Processing Record 37 of Set 9 | constantin daicoviciu
# Processing Record 38 of Set 9 | carutapera
# Processing Record 39 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 40 of Set 9 | namibe
# Processing Record 41 of Set 9 | porto torres
# Processing Record 42 of Set 9 | haradok
# Processing Record 43 of Set 9 | muroto
# Processing Record 44 of Set 9 | iquitos
# Processing Record 45 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 9 | oytal
# Processing Record 47 of Set 9 | malanje
# Processing Record 48 of Set 9 | jega
# Processing Record 49 of Set 9 | la romana
# Processing Record 50 of Set 9 | durango
# Processing Record 1 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 2 of Set 10 | santa cruz cabralia
# Processing Record 3 of Set 10 | xiongzhou
# Processing Record 4 of Set 10 | richards bay
# Processing Record 5 of Set 10 | qrendi
# Processing Record 6 of Set 10 | nishihara
# Processing Record 7 of Set 10 | dingle
# Processing Record 8 of Set 10 | paka
# Processing Record 9 of Set 10 | kattivakkam
# Processing Record 10 of Set 10 | liwale
# Processing Record 11 of Set 10 | marabba
# Processing Record 12 of Set 10 | bata
# Processing Record 13 of Set 10 | acapulco
# Processing Record 14 of Set 10 | ouidah
# Processing Record 15 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 16 of Set 10 | weligama
# Processing Record 17 of Set 10 | sawakin
# Processing Record 18 of Set 10 | inta
# Processing Record 19 of Set 10 | sakti
# Processing Record 20 of Set 10 | san carlos de bariloche
# Processing Record 21 of Set 10 | nabire
# Processing Record 22 of Set 10 | motozintla
# Processing Record 23 of Set 10 | cayeli
# Processing Record 24 of Set 10 | chodziez
# Processing Record 25 of Set 10 | grandview
# Processing Record 26 of Set 10 | nantucket
# Processing Record 27 of Set 10 | martapura
# Processing Record 28 of Set 10 | freeport
# Processing Record 29 of Set 10 | hambantota
# Processing Record 30 of Set 10 | dicabisagan
# Processing Record 31 of Set 10 | launceston
# Processing Record 32 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 10 | toguchin
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | ayorou
# Processing Record 36 of Set 10 | mailsi
# Processing Record 37 of Set 10 | grenville
# Processing Record 38 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 10 | traverse city
# Processing Record 41 of Set 10 | walvis bay
# Processing Record 42 of Set 10 | ozinki
# Processing Record 43 of Set 10 | poronaysk
# Processing Record 44 of Set 10 | nieves
# Processing Record 45 of Set 10 | saint anthony
# Processing Record 46 of Set 10 | sirmaur
# Processing Record 47 of Set 10 | podor
# Processing Record 48 of Set 10 | iquique
# Processing Record 49 of Set 10 | hirara
# Processing Record 50 of Set 10 | asau
# Processing Record 1 of Set 11 | mizan teferi
# Processing Record 2 of Set 11 | manadhoo
# Processing Record 3 of Set 11 | guerrero negro
# Processing Record 4 of Set 11 | awbari
# Processing Record 5 of Set 11 | male
# Processing Record 6 of Set 11 | chicama
# Processing Record 7 of Set 11 | samandag
# Processing Record 8 of Set 11 | sisimiut
# Processing Record 9 of Set 11 | beloha
# Processing Record 10 of Set 11 | owando
# Processing Record 11 of Set 11 | kokopo
# Processing Record 12 of Set 11 | temyasovo
# Processing Record 13 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 11 | irtyshskiy
# Processing Record 15 of Set 11 | jumla
# Processing Record 16 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 17 of Set 11 | remanso
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | sergeyevka
# Processing Record 20 of Set 11 | tual
# Processing Record 21 of Set 11 | tura
# Processing Record 22 of Set 11 | syracuse
# Processing Record 23 of Set 11 | neftegorsk
# Processing Record 24 of Set 11 | zyryanka
# Processing Record 25 of Set 11 | haines junction
# Processing Record 26 of Set 11 | sanming
# Processing Record 27 of Set 11 | husavik
# Processing Record 28 of Set 11 | nhulunbuy
# Processing Record 29 of Set 11 | leningradskiy
# Processing Record 30 of Set 11 | amantea
# Processing Record 31 of Set 11 | upata
# Processing Record 32 of Set 11 | okakarara
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | koumac
# Processing Record 35 of Set 11 | parkes
# Processing Record 36 of Set 11 | barvinkove
# Processing Record 37 of Set 11 | waingapu
# Processing Record 38 of Set 11 | choszczno
# Processing Record 39 of Set 11 | cabedelo
# Processing Record 40 of Set 11 | tahoua
# Processing Record 41 of Set 11 | zhuanghe
# Processing Record 42 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 11 | aquiraz
# Processing Record 44 of Set 11 | aracuai
# Processing Record 45 of Set 11 | ukiah
# Processing Record 46 of Set 11 | kyra
# Processing Record 47 of Set 11 | thyboron
# Processing Record 48 of Set 11 | semporna
# Processing Record 49 of Set 11 | sangar
# Processing Record 50 of Set 11 | odienne
# Processing Record 1 of Set 12 | necochea
# Processing Record 2 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 12 | nyurba
# Processing Record 4 of Set 12 | igarka
# Processing Record 5 of Set 12 | bocas del toro
# Processing Record 6 of Set 12 | krasnyy chikoy
# Processing Record 7 of Set 12 | kavaratti
# Processing Record 8 of Set 12 | moranbah
# Processing Record 9 of Set 12 | hathras
# Processing Record 10 of Set 12 | mandan
# Processing Record 11 of Set 12 | iralaya
# Processing Record 12 of Set 12 | barcelona
# Processing Record 13 of Set 12 | kumluca
# Processing Record 14 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 12 | vila franca do campo
# Processing Record 16 of Set 12 | tekirdag
# Processing Record 17 of Set 12 | rio cuarto
# Processing Record 18 of Set 12 | kajaani
# Processing Record 19 of Set 12 | kapit
# Processing Record 20 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 21 of Set 12 | paita
# Processing Record 22 of Set 12 | comodoro rivadavia
# Processing Record 23 of Set 12 | mocuba
# Processing Record 24 of Set 12 | hohhot
# Processing Record 25 of Set 12 | gamba
# Processing Record 26 of Set 12 | vallenar
# Processing Record 27 of Set 12 | bandarbeyla
# Processing Record 28 of Set 12 | dubovka
# Processing Record 29 of Set 12 | araouane
# Processing Record 30 of Set 12 | astoria
# Processing Record 31 of Set 12 | leninskoye
# Processing Record 32 of Set 12 | severnoye
# Processing Record 33 of Set 12 | tikaitnagar
# Processing Record 34 of Set 12 | tagusao
# Processing Record 35 of Set 12 | opuwo
# Processing Record 36 of Set 12 | mabaruma
# Processing Record 37 of Set 12 | kabanjahe
# Processing Record 38 of Set 12 | alugan
# Processing Record 39 of Set 12 | colonia
# Processing Record 40 of Set 12 | shahpura
# Processing Record 41 of Set 12 | labuan
# Processing Record 42 of Set 12 | havre-saint-pierre
# Processing Record 43 of Set 12 | mackay
# Processing Record 44 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 12 | kavieng
# Processing Record 46 of Set 12 | jasper
# Processing Record 47 of Set 12 | lujiang
# Processing Record 48 of Set 12 | san rafael
# Processing Record 49 of Set 12 | meulaboh
# Processing Record 50 of Set 12 | smithers
# Processing Record 1 of Set 13 | katherine
# Processing Record 2 of Set 13 | vanimo
# Processing Record 3 of Set 13 | develi
# Processing Record 4 of Set 13 | atikokan
# Processing Record 5 of Set 13 | daru
# Processing Record 6 of Set 13 | ahipara
# Processing Record 7 of Set 13 | tautira
# Processing Record 8 of Set 13 | aksarka
# Processing Record 9 of Set 13 | minab
# Processing Record 10 of Set 13 | verkhoyansk
# Processing Record 11 of Set 13 | goderich
# Processing Record 12 of Set 13 | sunbury
# Processing Record 13 of Set 13 | flinders
# Processing Record 14 of Set 13 | nioro
# Processing Record 15 of Set 13 | sirjan
# Processing Record 16 of Set 13 | kincardine
# Processing Record 17 of Set 13 | revelstoke
# Processing Record 18 of Set 13 | taganak
# Processing Record 19 of Set 13 | kununurra
# Processing Record 20 of Set 13 | buta
# Processing Record 21 of Set 13 | azad shahr
# Processing Record 22 of Set 13 | beringovskiy
# Processing Record 23 of Set 13 | monywa
# Processing Record 24 of Set 13 | dudinka
# Processing Record 25 of Set 13 | nizhnyaya omka
# Processing Record 26 of Set 13 | handwara
# City not found. Skipping...
# Processing Record 27 of Set 13 | krasnoborsk
# Processing Record 28 of Set 13 | thanh hoa
# Processing Record 29 of Set 13 | oga
# Processing Record 30 of Set 13 | san quintin
# Processing Record 31 of Set 13 | turtas
# Processing Record 32 of Set 13 | horta
# Processing Record 33 of Set 13 | fare
# Processing Record 34 of Set 13 | bonavista
# Processing Record 35 of Set 13 | marawi
# Processing Record 36 of Set 13 | baruun-urt
# Processing Record 37 of Set 13 | alta floresta
# Processing Record 38 of Set 13 | ossora
# Processing Record 39 of Set 13 | anchorage
# Processing Record 40 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 41 of Set 13 | dagohoy
# Processing Record 42 of Set 13 | paralimni
# Processing Record 43 of Set 13 | jiazi
# Processing Record 44 of Set 13 | almaty
# Processing Record 45 of Set 13 | bilma
# Processing Record 46 of Set 13 | komsomolskiy
# Processing Record 47 of Set 13 | arkhangelos
# City not found. Skipping...
# Processing Record 48 of Set 13 | bhuban
# Processing Record 49 of Set 13 | tucuman
# Processing Record 50 of Set 13 | bosaso
# Processing Record 1 of Set 14 | karacabey
# Processing Record 2 of Set 14 | chatsu
# City not found. Skipping...
# Processing Record 3 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 14 | kaeo
# Processing Record 5 of Set 14 | antsohihy
# Processing Record 6 of Set 14 | prata
# Processing Record 7 of Set 14 | ushtobe
# Processing Record 8 of Set 14 | trabzon
# Processing Record 9 of Set 14 | saint-michel-des-saints
# Processing Record 10 of Set 14 | dwarka
# Processing Record 11 of Set 14 | rawson
# Processing Record 12 of Set 14 | katiola
# Processing Record 13 of Set 14 | palauig
# Processing Record 14 of Set 14 | deep river
# Processing Record 15 of Set 14 | lesozavodsk
# Processing Record 16 of Set 14 | fairbanks
# Processing Record 17 of Set 14 | vaitape
# Processing Record 18 of Set 14 | muyezerskiy
# Processing Record 19 of Set 14 | tortoli
# Processing Record 20 of Set 14 | cherskiy
# Processing Record 21 of Set 14 | sambava
# Processing Record 22 of Set 14 | haguenau
# Processing Record 23 of Set 14 | guelengdeng
# City not found. Skipping...
# Processing Record 24 of Set 14 | marystown
# Processing Record 25 of Set 14 | sola
# Processing Record 26 of Set 14 | grootfontein
# Processing Record 27 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 14 | batemans bay
# Processing Record 29 of Set 14 | muhos
# Processing Record 30 of Set 14 | nagato
# Processing Record 31 of Set 14 | shingu
# Processing Record 32 of Set 14 | general roca
# Processing Record 33 of Set 14 | stara pazova
# Processing Record 34 of Set 14 | sanjwal
# Processing Record 35 of Set 14 | naze
# Processing Record 36 of Set 14 | atagay
# Processing Record 37 of Set 14 | gallup
# Processing Record 38 of Set 14 | narsaq
# Processing Record 39 of Set 14 | waddan
# Processing Record 40 of Set 14 | pedernales
# Processing Record 41 of Set 14 | ransang
# Processing Record 42 of Set 14 | acari
# Processing Record 43 of Set 14 | slave lake
# Processing Record 44 of Set 14 | mount gambier
# Processing Record 45 of Set 14 | ahuimanu
# Processing Record 46 of Set 14 | alcaniz
# Processing Record 47 of Set 14 | saint-junien
# Processing Record 48 of Set 14 | ishigaki
# Processing Record 49 of Set 14 | batagay-alyta
# Processing Record 50 of Set 14 | lavrentiya
# Processing Record 1 of Set 15 | bud
# Processing Record 2 of Set 15 | te anau
# Processing Record 3 of Set 15 | ulagan
# Processing Record 4 of Set 15 | baykit
# Processing Record 5 of Set 15 | lappeenranta
# Processing Record 6 of Set 15 | gurupi
# Processing Record 7 of Set 15 | chapais
# Processing Record 8 of Set 15 | tecoanapa
# Processing Record 9 of Set 15 | kundiawa
# Processing Record 10 of Set 15 | bubaque
# Processing Record 11 of Set 15 | bonfim
# Processing Record 12 of Set 15 | manitowoc
# Processing Record 13 of Set 15 | leh
# Processing Record 14 of Set 15 | arrecife
# Processing Record 15 of Set 15 | boguchar
# Processing Record 16 of Set 15 | appleton
# Processing Record 17 of Set 15 | peniche
# Processing Record 18 of Set 15 | pathein
# Processing Record 19 of Set 15 | misratah
# Processing Record 20 of Set 15 | ostersund
# Processing Record 21 of Set 15 | wahiawa
# Processing Record 22 of Set 15 | keokuk
# Processing Record 23 of Set 15 | cockburn town
# Processing Record 24 of Set 15 | deputatskiy
# Processing Record 25 of Set 15 | arona
# Processing Record 26 of Set 15 | raudeberg
# Processing Record 27 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 15 | xichang
# Processing Record 29 of Set 15 | takoradi
# Processing Record 30 of Set 15 | somondoco
# Processing Record 31 of Set 15 | port augusta
# Processing Record 32 of Set 15 | genc
# Processing Record 33 of Set 15 | saint-pierre
# Processing Record 34 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 15 | aklavik
# Processing Record 36 of Set 15 | turinsk
# Processing Record 37 of Set 15 | shizuishan
# Processing Record 38 of Set 15 | luckenwalde
# Processing Record 39 of Set 15 | palmer
# Processing Record 40 of Set 15 | caucaia
# Processing Record 41 of Set 15 | jundubah
# City not found. Skipping...
# Processing Record 42 of Set 15 | lingyuan
# Processing Record 43 of Set 15 | parana
# Processing Record 44 of Set 15 | verkhnyaya toyma
# Processing Record 45 of Set 15 | port hedland
# Processing Record 46 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 15 | khandyga
# Processing Record 48 of Set 15 | uddevalla
# Processing Record 49 of Set 15 | soe
# Processing Record 50 of Set 15 | nosivka
# Processing Record 1 of Set 16 | oktyabrskiy
# Processing Record 2 of Set 16 | keningau
# Processing Record 3 of Set 16 | kumeny
# Processing Record 4 of Set 16 | hamilton
# Processing Record 5 of Set 16 | prince rupert
# Processing Record 6 of Set 16 | birao
# Processing Record 7 of Set 16 | balakhta
# Processing Record 8 of Set 16 | puerto madryn
# Processing Record 9 of Set 16 | askino
# Processing Record 10 of Set 16 | noumea
# Processing Record 11 of Set 16 | mazabuka
# Processing Record 12 of Set 16 | hagen
# Processing Record 13 of Set 16 | kutum
# Processing Record 14 of Set 16 | udachnyy
# Processing Record 15 of Set 16 | erenhot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bengkulu  -3.8004  102.2655     75.60        89          98
# 1   Saint-Augustin  51.2260  -58.6502     48.47        56         100
# 2           Barrow  71.2906 -156.7887     39.22        93          75
# 3           Torbay  47.6666  -52.7314     59.58        66          75
# 4              Ayr  55.4627   -4.6339     63.32        77          20
# 5            Ancud -41.8697  -73.8203     44.22        82          96
# 6       Sao Filipe  14.8961  -24.4956     79.18        72         100
# 7          Mataura -46.1927  168.8643     46.47        90          80
# 8            Vaini -21.2000 -175.2000     73.56        83          20
# 9  Dzilam Gonzalez  21.2833  -88.9333     86.18        62           8
#
#    Wind Speed Country Current Description                 Date
# 0        5.82      ID     overcast clouds  2022-09-19 15:20:42
# 1       14.14      CA     overcast clouds  2022-09-19 15:27:23
# 2        8.05      US       broken clouds  2022-09-19 15:19:40
# 3       20.71      CA       broken clouds  2022-09-19 15:22:40
# 4        5.75      GB          few clouds  2022-09-19 15:28:34
# 5        7.72      CL          light rain  2022-09-19 15:20:20
# 6        8.03      CV     overcast clouds  2022-09-19 15:20:44
# 7        2.98      NZ          light rain  2022-09-19 15:20:26
# 8        6.91      TO          few clouds  2022-09-19 15:20:22
# 9        3.31      MX           clear sky  2022-09-19 15:28:34

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Bengkulu      ID  -3.8004  102.2655     75.60        89
# 1    Saint-Augustin      CA  51.2260  -58.6502     48.47        56
# 2            Barrow      US  71.2906 -156.7887     39.22        93
# 3            Torbay      CA  47.6666  -52.7314     59.58        66
# 4               Ayr      GB  55.4627   -4.6339     63.32        77
# ..              ...     ...      ...       ...       ...       ...
# 692        Mazabuka      ZM -15.8560   27.7480     87.12        17
# 693           Hagen      DE  51.3500    7.4667     58.14        85
# 694           Kutum      SD  14.2000   24.6667     89.47        23
# 695        Udachnyy      RU  66.4167  112.4000     32.58        99
# 696         Erenhot      CN  43.6475  111.9767     52.47        27
#
#      Cloudiness  Wind Speed Current Description
# 0            98        5.82     overcast clouds
# 1           100       14.14     overcast clouds
# 2            75        8.05       broken clouds
# 3            75       20.71       broken clouds
# 4            20        5.75          few clouds
# ..          ...         ...                 ...
# 692          17        2.98          few clouds
# 693          62        8.01     very heavy rain
# 694          78        6.40       broken clouds
# 695         100        6.06          light snow
# 696           6        4.50           clear sky
#
# [697 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
