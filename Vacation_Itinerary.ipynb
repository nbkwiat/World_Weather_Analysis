# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(50)
# Out:
#     City_ID              City Country  Max Temp Current Description      Lat  \
# 0         0          Bengkulu      ID     75.60     overcast clouds  -3.8004
# 1         6        Sao Filipe      CV     79.18     overcast clouds  14.8961
# 2         9   Dzilam Gonzalez      MX     86.18           clear sky  21.2833
# 3        11   Arraial Do Cabo      BR     78.76           clear sky -22.9661
# 4        12    Cabo San Lucas      MX     81.52     overcast clouds  22.8909
# 5        21               Gat      IL     81.28       broken clouds  31.6100
# 6        24          Dong Hoi      VN     80.98     overcast clouds  17.4833
# 7        25          Beroroha      MG     84.74           clear sky -21.6667
# 8        28  Praia Da Vitoria      PT     80.85          few clouds  38.7333
# 9        29           Qesarya      IL     82.33    scattered clouds  32.5189
# 10       30             Kapaa      US     78.10       broken clouds  22.0752
# 11       32           Kahului      US     77.85    scattered clouds  20.8947
# 12       36            Albany      US     77.95       broken clouds  42.6001
# 13       44          Monrovia      LR     80.37       broken clouds   6.3005
# 14       58             Bayir      TR     79.32           clear sky  37.2687
# 15       60         Hithadhoo      MV     82.54       broken clouds  -0.6000
# 16       65     San Policarpo      PH     78.91     overcast clouds  12.1791
# 17       66           Calamar      CO     81.43     overcast clouds  10.2511
# 18       70        Georgetown      MY     83.89          light rain   5.4112
# 19       72        Butaritari      KI     81.68          light rain   3.0707
# 20       77          Cam Ranh      VN     78.76    scattered clouds  11.9214
# 21       78           Buckeye      US     87.03           clear sky  33.3703
# 22       79          Celestun      MX     82.67           clear sky  20.8667
# 23       80           Rangpur      BD     81.55          few clouds  25.7500
# 24       81    Ribeira Grande      PT     81.00    scattered clouds  38.5167
# 25       93    Mount Pleasant      US     84.06       broken clouds  32.7941
# 26       96       Pundaguitan      PH     83.84     overcast clouds   6.3711
# 27       97           Telchac      MX     86.49           clear sky  21.2000
# 28      100     San Cristobal      VE     75.38     overcast clouds   7.7669
# 29      104         Ratnagiri      IN     77.63     overcast clouds  16.9833
# 30      105            Omboue      GA     79.79       broken clouds  -1.5746
# 31      107          Mirzapur      IN     78.76       moderate rain  25.1500
# 32      114         High Rock      BS     87.82     overcast clouds  26.6208
# 33      115         Bathsheba      BB     88.41          few clouds  13.2167
# 34      118   Puerto Ayacucho      VE     86.63       broken clouds   5.6639
# 35      122            Marzuq      YE     85.53          few clouds  14.4000
# 36      124         Alyangula      AU     77.49     overcast clouds -13.8483
# 37      125            Olinda      BR     82.13          few clouds  -8.0089
# 38      126            Padang      ID     77.05     overcast clouds  -0.9492
# 39      127          Bo Phloi      TH     75.31     overcast clouds  14.3236
# 40      129               Sur      OM     84.81           clear sky  22.5667
# 41      132              Biak      ID     76.26    scattered clouds  -0.9131
# 42      134          Ban Dung      TH     81.10     overcast clouds  17.6990
# 43      135            Bethel      US     81.55           clear sky  41.3712
# 44      136          Katsuura      JP     80.38     overcast clouds  35.1333
# 45      137           Bojnurd      IR     80.55           clear sky  37.4747
# 46      141     Pervomayskoye      RU     84.87          few clouds  43.9190
# 47      145        Banda Aceh      ID     80.10     overcast clouds   5.5577
# 48      146          Acajutla      SV     81.32       broken clouds  13.5928
# 49      150              Mayo      US     85.17           clear sky  38.8876
#
#          Lng                                         Hotel Name
# 0   102.2655                               Grage Hotel Bengkulu
# 1   -24.4956                                      Hotel Xaguate
# 2   -88.9333                                            posadas
# 3   -42.0278                                Pousada Porto Praia
# 4  -109.9124                             Hotel Tesoro Los Cabos
# 5    34.7642                                           OlusHome
# 6   106.6000                                     Nam Long Hotel
# 7    45.1667                                Dibbo areaمنطقة دبو
# 8   -27.0667                                     Hotel Branco I
# 9    34.9046          Dan Caesarea Resort - Happiness Is Around
# 10 -159.3190                Sheraton Kauai Coconut Beach Resort
# 11 -156.4700                                 Maui Seaside Hotel
# 12  -73.9662                                Dibbo areaمنطقة دبو
# 13  -10.7969                                         Sunset Inn
# 14   28.2167                                      Hotel Babadag
# 15   73.0833                                  Scoop Guest House
# 16  125.5072                                  Agapita M. Nicart
# 17  -74.9146                                    Hostal Katyalex
# 18  100.3354                                     Cititel Penang
# 19  172.7902                                 Isles Sunset Lodge
# 20  109.1591                                OYO 598 Peony Hotel
# 21 -112.5838  Buckeye Motor Hotel- CALL FOR PRICING, AVAILAB...
# 22  -90.4000                                       Posada Lilia
# 23   89.2500                                  Hotel Shah Amanat
# 24  -28.7000                                Quinta da Meia Eira
# 25  -79.8626                        Best Western Patriots Point
# 26  126.1689                      Leonardo Family Beach House 1
# 27  -89.2667                                     Daniel agullar
# 28  -72.2250                                           Pirineos
# 29   73.3000                                     Hotel Landmark
# 30    9.2618                                        Hotel Olako
# 31   82.5833                                     Hotel Yash Inn
# 32  -78.2833                        Hideaway Bahamas Beach Club
# 33  -59.5167                                     Atlantis Hotel
# 34  -67.6236                         Posada Turistica Manapiare
# 35   46.4667                                         حيد القفلة
# 36  136.4192                               Groote Eylandt Lodge
# 37  -34.8553                           Flat Quatro Rodas Olinda
# 38  100.3543                                     Mercure Padang
# 39   99.5161          แอท เมืองพลอย รีสอร์ท At MuangPloy Resort
# 40   59.5289                                    Sur Plaza Hotel
# 41  122.8766                                     Penginapan Kim
# 42  103.2596                                      Heuan Na Khee
# 43  -73.4140                      Courtyard by Marriott Danbury
# 44  140.3000                            Katsuura Hotel Mikazuki
# 45   57.3290                               Hotel negin bojnourd
# 46   46.7102                                Dibbo areaمنطقة دبو
# 47   95.3222                            OYO 884 Rumoh PMI Hotel
# 48  -89.8275                                           Laureles
# 49  -76.5119               Resorts Resource Group International

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Cabo San Lucas"]
vacation_end = vacation_df.loc[vacation_df['City'] == "Cabo San Lucas"]
vacation_stop1 = vacation_df.loc[vacation_df['City'] == "Coahuayana"]
vacation_stop2 = vacation_df.loc[vacation_df['City'] == "Acapulco"]
vacation_stop3 = vacation_df.loc[vacation_df['City'] == "Tecoanapa"] 
vacation_start
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 4       12  Cabo San Lucas      MX     81.52     overcast clouds  22.8909
#
#         Lng              Hotel Name
# 4 -109.9124  Hotel Tesoro Los Cabos

# %%
vacation_stop1
# Out:
#     City_ID        City Country  Max Temp Current Description      Lat  \
# 86      256  Coahuayana      MX     76.21     overcast clouds  18.7333
#
#          Lng                         Hotel Name
# 86 -103.6833  El rranchito michuacan de ocampos

# %%
vacation_stop2
# Out:
#      City_ID      City Country  Max Temp Current Description      Lat  \
# 160      416  Acapulco      MX     80.42     overcast clouds  16.8634
#
#          Lng                 Hotel Name
# 160 -99.8901  HS Hotsson Smart Acapulco

# %%
vacation_stop3
# Out:
#      City_ID       City Country  Max Temp Current Description      Lat    Lng  \
# 252      643  Tecoanapa      MX     80.13     overcast clouds  16.5167 -98.75
#
#           Hotel Name
# 252  Hotel Manglares

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (vacation_df.loc[4]["Lat"],vacation_df.loc[4]["Lng"])
end = (vacation_df.loc[4]["Lat"],vacation_df.loc[4]["Lng"])
stop1 = (vacation_df.loc[86]["Lat"],vacation_df.loc[86]["Lng"])
stop2 = (vacation_df.loc[160]["Lat"],vacation_df.loc[160]["Lng"])
stop3 = (vacation_df.loc[252]["Lat"],vacation_df.loc[252]["Lng"])

waypoints = [stop1, stop2, stop3]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps.datasets

gmaps.configure(api_key=g_key)

fig = gmaps.figure()

driving = gmaps.directions_layer(start, end, waypoints=waypoints, travel_mode='DRIVING')

fig.add_layer(driving)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end], ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0       12  Cabo San Lucas      MX     81.52     overcast clouds  22.8909
# 1      256      Coahuayana      MX     76.21     overcast clouds  18.7333
# 2      416        Acapulco      MX     80.42     overcast clouds  16.8634
# 3      643       Tecoanapa      MX     80.13     overcast clouds  16.5167
# 4       12  Cabo San Lucas      MX     81.52     overcast clouds  22.8909
#
#         Lng                         Hotel Name
# 0 -109.9124             Hotel Tesoro Los Cabos
# 1 -103.6833  El rranchito michuacan de ocampos
# 2  -99.8901          HS Hotsson Smart Acapulco
# 3  -98.7500                    Hotel Manglares
# 4 -109.9124             Hotel Tesoro Los Cabos

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat","Lng"]]
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
